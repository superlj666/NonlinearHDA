# %% [markdown]
# ### Exp 1: Effection of feature size

# %%
import matplotlib.pyplot as plt
import pickle
import numpy as np
import matplotlib as mpl
mpl.rcParams['pdf.fonttype'] = 42
mpl.rcParams['ps.fonttype'] = 42

with open('./results/exp1_mnist.pkl', 'rb') as f:
    record_ = pickle.load(f)

index=[0,1,2,3]

f = plt.figure()
plt.plot(record_['lambda_arr'], np.mean(record_['rf_error'][index,:], 2).T,linewidth=2)
plt.axvline(x=1, ymin=0, ymax=5, linestyle=':', color='k')
plt.xlabel('$\gamma = p / m$', fontsize=20)
plt.ylabel('Test Error', fontsize=20)
plt.tick_params(axis='both', which='major', labelsize=15)
plt.tick_params(axis='both', which='minor', labelsize=15)
plt.legend(['Ridgeless Regression', 'Ridge Regression, $\lambda=10^{-6}$', 'Ridge Regression, $\lambda=10^{-4}$', 'Ridge Regression, $\lambda=10^{-2}$'], fontsize=12)
f.savefig('./results/exp1_random_Fourier_feature_error.pdf', bbox_inches='tight')

f = plt.figure()
plt.plot(record_['lambda_arr'], np.mean(record_['rf_loss'][index,:], 2).T,linewidth=2)
plt.ylim([0, 0.6])
plt.axvline(x=1, ymin=0, ymax=5, linestyle=':', color='k')
plt.xlabel('$\gamma = p / m$', fontsize=20)
plt.ylabel('Square loss', fontsize=20)
plt.tick_params(axis='both', which='major', labelsize=15)
plt.tick_params(axis='both', which='minor', labelsize=15)
plt.legend(['Ridgeless Regression', 'Ridge Regression, $\lambda=10^{-6}$', 'Ridge Regression, $\lambda=10^{-4}$', 'Ridge Regression, $\lambda=10^{-2}$'], fontsize=12)
f.savefig('./results/exp1_random_Fourier_feature_loss.pdf', bbox_inches='tight')

f = plt.figure()
plt.plot(record_['lambda_arr'], np.mean(record_['kappa_arr'][index,:], 2).T,linewidth=2)
plt.axvline(x=1, ymin=0, ymax=5, linestyle=':', color='k')
plt.xlabel('$\gamma = p / m$', fontsize=20)
plt.ylabel('$\kappa$', fontsize=20)
plt.tick_params(axis='both', which='major', labelsize=15)
plt.tick_params(axis='both', which='minor', labelsize=15)
plt.legend(['Ridgeless Regression', 'Ridge Regression, $\lambda=10^{-6}$', 'Ridge Regression, $\lambda=10^{-4}$', 'Ridge Regression, $\lambda=10^{-2}$'], fontsize=12)
f.savefig('./results/exp1_random_Fourier_feature_kappa.pdf', bbox_inches='tight')

f = plt.figure()
plt.semilogy(record_['lambda_arr'], np.mean(record_['df2_arr'][index,:], 2).T,linewidth=2)
plt.axvline(x=1, ymin=0, ymax=5, linestyle=':', color='k')
plt.xlabel('$\gamma = p / m$', fontsize=20)
plt.ylabel('$\widehat{df}_2(\kappa)$', fontsize=20)
plt.tick_params(axis='both', which='major', labelsize=15)
plt.tick_params(axis='both', which='minor', labelsize=15)
plt.legend(['Ridgeless Regression', 'Ridge Regression, $\lambda=10^{-6}$', 'Ridge Regression, $\lambda=10^{-4}$', 'Ridge Regression, $\lambda=10^{-2}$'], fontsize=12)
f.savefig('./results/exp1_random_Fourier_feature_df2.pdf', bbox_inches='tight')

# %% [markdown]
# ### Exp 2: Effect of subsampling size

# %%
import matplotlib.pyplot as plt
import pickle
import numpy as np
import matplotlib as mpl
mpl.rcParams['pdf.fonttype'] = 42
mpl.rcParams['ps.fonttype'] = 42

with open('./results/exp2_subsampling_mnist.pkl', 'rb') as f:
    record_ = pickle.load(f)

index=[0,1,2,3]

f = plt.figure()
plt.plot(record_['M_m_arr'], np.mean(record_['rf_error'][index,:], 2).T,linewidth=2)
plt.axvline(x=1, ymin=0, ymax=5, linestyle=':', color='k')
plt.xlabel('$\gamma = p / m$', fontsize=20)
plt.ylabel('Test Error', fontsize=20)
plt.tick_params(axis='both', which='major', labelsize=15)
plt.tick_params(axis='both', which='minor', labelsize=15)
plt.legend(['Ridgeless Regression', 'Ridge Regression, $\lambda=10^{-6}$', 'Ridge Regression, $\lambda=10^{-4}$', 'Ridge Regression, $\lambda=10^{-2}$'], fontsize=12)
f.savefig('./results/exp2_subsampling_error.pdf', bbox_inches='tight')

f = plt.figure()
plt.plot(record_['M_m_arr'], np.mean(record_['rf_loss'][index,:], 2).T,linewidth=2)
plt.ylim([0, 0.6])
plt.axvline(x=1, ymin=0, ymax=5, linestyle=':', color='k')
plt.xlabel('$\gamma = p / m$', fontsize=20)
plt.ylabel('Square loss', fontsize=20)
plt.tick_params(axis='both', which='major', labelsize=15)
plt.tick_params(axis='both', which='minor', labelsize=15)
plt.legend(['Ridgeless Regression', 'Ridge Regression, $\lambda=10^{-6}$', 'Ridge Regression, $\lambda=10^{-4}$', 'Ridge Regression, $\lambda=10^{-2}$'], fontsize=12)
f.savefig('./results/exp2_subsampling_loss.pdf', bbox_inches='tight')

f = plt.figure()
plt.plot(record_['M_m_arr'], np.mean(record_['kappa_arr'][index,:], 2).T,linewidth=2)
plt.axvline(x=1, ymin=0, ymax=5, linestyle=':', color='k')
plt.xlabel('$\gamma = p / m$', fontsize=20)
plt.ylabel('$\kappa$', fontsize=20)
plt.tick_params(axis='both', which='major', labelsize=15)
plt.tick_params(axis='both', which='minor', labelsize=15)
plt.legend(['Ridgeless Regression', 'Ridge Regression, $\lambda=10^{-6}$', 'Ridge Regression, $\lambda=10^{-4}$', 'Ridge Regression, $\lambda=10^{-2}$'], fontsize=12)
f.savefig('./results/exp2_subsampling_kappa.pdf', bbox_inches='tight')

f = plt.figure()
plt.semilogy(record_['M_m_arr'], np.mean(record_['df2_arr'][index,:], 2).T,linewidth=2)
plt.axvline(x=1, ymin=0, ymax=5, linestyle=':', color='k')
plt.xlabel('$\gamma = p / m$', fontsize=20)
plt.ylabel('$\widehat{df}_2(\kappa)$', fontsize=20)
plt.tick_params(axis='both', which='major', labelsize=15)
plt.tick_params(axis='both', which='minor', labelsize=15)
plt.legend(['Ridgeless Regression', 'Ridge Regression, $\lambda=10^{-6}$', 'Ridge Regression, $\lambda=10^{-4}$', 'Ridge Regression, $\lambda=10^{-2}$'], fontsize=12)
f.savefig('./results/exp2_subsampling_df2.pdf', bbox_inches='tight')

# %% [markdown]
# ### Exp2: Effect of ROS

# %%
import matplotlib.pyplot as plt
import pickle
import numpy as np
import matplotlib as mpl
mpl.rcParams['pdf.fonttype'] = 42
mpl.rcParams['ps.fonttype'] = 42

with open('./results/exp2_ros_mnist.pkl', 'rb') as f:
    record_ = pickle.load(f)

index=[0,1,2,3]

f = plt.figure()
plt.plot(record_['M_m_arr'], np.mean(record_['rf_error'][index,:], 2).T,linewidth=2)
plt.axvline(x=1, ymin=0, ymax=5, linestyle=':', color='k')
plt.xlabel('$\gamma = p / m$', fontsize=20)
plt.ylabel('Test Error', fontsize=20)
plt.tick_params(axis='both', which='major', labelsize=15)
plt.tick_params(axis='both', which='minor', labelsize=15)
plt.legend(['Ridgeless Regression', 'Ridge Regression, $\lambda=10^{-6}$', 'Ridge Regression, $\lambda=10^{-4}$', 'Ridge Regression, $\lambda=10^{-2}$'], fontsize=12)
f.savefig('./results/exp2_ros_error.pdf', bbox_inches='tight')

f = plt.figure()
plt.plot(record_['M_m_arr'], np.mean(record_['rf_loss'][index,:], 2).T,linewidth=2)
plt.ylim([0, 0.6])
plt.axvline(x=1, ymin=0, ymax=5, linestyle=':', color='k')
plt.xlabel('$\gamma = p / m$', fontsize=20)
plt.ylabel('Square loss', fontsize=20)
plt.tick_params(axis='both', which='major', labelsize=15)
plt.tick_params(axis='both', which='minor', labelsize=15)
plt.legend(['Ridgeless Regression', 'Ridge Regression, $\lambda=10^{-6}$', 'Ridge Regression, $\lambda=10^{-4}$', 'Ridge Regression, $\lambda=10^{-2}$'], fontsize=12)
f.savefig('./results/exp2_ros_loss.pdf', bbox_inches='tight')

f = plt.figure()
plt.plot(record_['M_m_arr'], np.mean(record_['kappa_arr'][index,:], 2).T,linewidth=2)
plt.axvline(x=1, ymin=0, ymax=5, linestyle=':', color='k')
plt.xlabel('$\gamma = p / m$', fontsize=20)
plt.ylabel('$\kappa$', fontsize=20)
plt.tick_params(axis='both', which='major', labelsize=15)
plt.tick_params(axis='both', which='minor', labelsize=15)
plt.legend(['Ridgeless Regression', 'Ridge Regression, $\lambda=10^{-6}$', 'Ridge Regression, $\lambda=10^{-4}$', 'Ridge Regression, $\lambda=10^{-2}$'], fontsize=12)
f.savefig('./results/exp2_ros_kappa.pdf', bbox_inches='tight')

f = plt.figure()
plt.semilogy(record_['M_m_arr'], np.mean(record_['df2_arr'][index,:], 2).T,linewidth=2)
plt.axvline(x=1, ymin=0, ymax=5, linestyle=':', color='k')
plt.xlabel('$\gamma = p / m$', fontsize=20)
plt.ylabel('$\widehat{df}_2(\kappa)$', fontsize=20)
plt.tick_params(axis='both', which='major', labelsize=15)
plt.tick_params(axis='both', which='minor', labelsize=15)
plt.legend(['Ridgeless Regression', 'Ridge Regression, $\lambda=10^{-6}$', 'Ridge Regression, $\lambda=10^{-4}$', 'Ridge Regression, $\lambda=10^{-2}$'], fontsize=12)
f.savefig('./results/exp2_ros_df2.pdf', bbox_inches='tight')

# %% [markdown]
# ### Exp3: Tune regularization parameter $\lambda$

# %%
import matplotlib.pyplot as plt
import pickle
import numpy as np
import matplotlib as mpl
mpl.rcParams['pdf.fonttype'] = 42
mpl.rcParams['ps.fonttype'] = 42

with open('./results/exp3_lambda_mnist.pkl', 'rb') as f:
    record_ = pickle.load(f)

index=[0, 1, 2]

f = plt.figure()
plt.semilogx(record_['lambda_arr'], np.mean(record_['rf_error'], 2).T,linewidth=2)
plt.xlabel('Regularization parameter $\lambda$', fontsize=20)
plt.ylabel('Test Error', fontsize=20)
plt.tick_params(axis='both', which='major', labelsize=15)
plt.tick_params(axis='both', which='minor', labelsize=15)
plt.legend(['Ridge Regression $\gamma=0.5$', 'Ridge Regression $\gamma=1$', 'Ridge Regression $\gamma=2$'], fontsize=12)
f.savefig('./results/exp3_lambda_error.pdf', bbox_inches='tight')

f = plt.figure()
plt.semilogx(record_['lambda_arr'], np.mean(record_['rf_loss'], 2).T,linewidth=2)
plt.xlabel('Regularization parameter $\lambda$', fontsize=20)
plt.ylabel('Square loss', fontsize=20)
plt.tick_params(axis='both', which='major', labelsize=15)
plt.tick_params(axis='both', which='minor', labelsize=15)
plt.legend(['Ridge Regression $\gamma=0.5$', 'Ridge Regression $\gamma=1$', 'Ridge Regression $\gamma=2$'], fontsize=12)
f.savefig('./results/exp3_lambda_loss.pdf', bbox_inches='tight')

f = plt.figure()
plt.semilogx(record_['lambda_arr'], np.mean(record_['kappa_arr'], 2).T,linewidth=2)
plt.xlabel('Regularization parameter $\lambda$', fontsize=20)
plt.ylabel('$\kappa$', fontsize=20)
plt.tick_params(axis='both', which='major', labelsize=15)
plt.tick_params(axis='both', which='minor', labelsize=15)
plt.legend(['Ridge Regression $\gamma=0.5$', 'Ridge Regression $\gamma=1$', 'Ridge Regression $\gamma=2$'], fontsize=12)
f.savefig('./results/exp3_lambda_kappa.pdf', bbox_inches='tight')

f = plt.figure()
plt.semilogx(record_['lambda_arr'], np.mean(record_['df2_arr'], 2).T,linewidth=2)
plt.xlabel('Regularization parameter $\lambda$', fontsize=20)
plt.ylabel('$\widehat{df}_2(\kappa)$', fontsize=20)
plt.tick_params(axis='both', which='major', labelsize=15)
plt.tick_params(axis='both', which='minor', labelsize=15)
plt.legend(['Ridge Regression $\gamma=0.5$', 'Ridge Regression $\gamma=1$', 'Ridge Regression $\gamma=2$'], fontsize=12)
f.savefig('./results/exp3_lambda_df2.pdf', bbox_inches='tight')

# %% [markdown]
# ### Exp3: The effect of tunable feature mapping $\phi(x)$

# %%
import matplotlib.pyplot as plt
import pickle
import numpy as np
import matplotlib as mpl
mpl.rcParams['pdf.fonttype'] = 42
mpl.rcParams['ps.fonttype'] = 42

with open('./results/exp3_phi_mnist.pkl', 'rb') as f:
    record_ = pickle.load(f)

index=[0, 1, 2]

x_range = range(30)
f = plt.figure()
plt.semilogy(x_range, np.mean(record_['rf_loss'], 2).T, linewidth=2)
plt.semilogy(x_range, np.mean(record_['rf_loss_sgd'], 2).T, linewidth=2)
plt.xlabel('Training epochs $T$', fontsize=20)
plt.ylabel('Training Loss', fontsize=20)
plt.tick_params(axis='both', which='major', labelsize=15)
plt.tick_params(axis='both', which='minor', labelsize=15)
plt.legend(['RF $\gamma=0.5$', 'RF $\gamma=1$', 'RF $\gamma=2$', 'RF-SGD $\gamma=0.5$', 'RF-SGD $\gamma=1$', 'RF-SGD $\gamma=2$'], fontsize=12)
f.savefig('./results/exp3_phi_loss.pdf', bbox_inches='tight')

f = plt.figure()
plt.plot(x_range, np.mean(record_['rf_error'], 2).T, linewidth=2)
plt.plot(x_range, np.mean(record_['rf_error_sgd'], 2).T, linewidth=2)
plt.xlabel('Training epochs $T$', fontsize=20)
plt.ylabel('Test Error', fontsize=20)
plt.tick_params(axis='both', which='major', labelsize=15)
plt.tick_params(axis='both', which='minor', labelsize=15)
plt.legend(['RF $\gamma=0.5$', 'RF $\gamma=1$', 'RF $\gamma=2$', 'RF-SGD $\gamma=0.5$', 'RF-SGD $\gamma=1$', 'RF-SGD $\gamma=2$'], fontsize=12)
f.savefig('./results/exp3_phi_error.pdf', bbox_inches='tight')

f = plt.figure()
# plt.semilogy(x_range, np.mean(record_['kappa_arr'], 2).T, linewidth=2)
plt.semilogy(x_range, np.mean(record_['kappa_arr_sgd'], 2).T, linewidth=2)
plt.xlabel('Training epochs $T$', fontsize=20)
plt.ylabel('$\kappa$', fontsize=20)
plt.tick_params(axis='both', which='major', labelsize=15)
plt.tick_params(axis='both', which='minor', labelsize=15)
plt.legend(['RF $\gamma=0.5$', 'RF $\gamma=1$', 'RF $\gamma=2$', 'RF-SGD $\gamma=0.5$', 'RF-SGD $\gamma=1$', 'RF-SGD $\gamma=2$'], fontsize=12)
f.savefig('./results/exp3_phi_kappa.pdf', bbox_inches='tight')

f = plt.figure()
# plt.semilogy(x_range, np.mean(record_['df2_arr'], 2).T, linewidth=2)
plt.semilogy(x_range, np.mean(record_['df2_arr_sgd'], 2).T, linewidth=2)
plt.xlabel('Training epochs $T$', fontsize=20)
plt.ylabel('$\widehat{df}_2(\kappa)$', fontsize=20)
plt.tick_params(axis='both', which='major', labelsize=15)
plt.tick_params(axis='both', which='minor', labelsize=15)
plt.legend(['RF $\gamma=0.5$', 'RF $\gamma=1$', 'RF $\gamma=2$', 'RF-SGD $\gamma=0.5$', 'RF-SGD $\gamma=1$', 'RF-SGD $\gamma=2$'], fontsize=12)
f.savefig('./results/exp3_phi_df2.pdf', bbox_inches='tight')

# %%
import matplotlib.pyplot as plt
import pickle
import numpy as np
import matplotlib as mpl
mpl.rcParams['pdf.fonttype'] = 42
mpl.rcParams['ps.fonttype'] = 42

dataset = 'usps'

with open('./results/exp4_{}.pkl'.format(dataset), 'rb') as f:
    record_ = pickle.load(f)

x_range = range(30)
f = plt.figure()
plt.semilogy(x_range, np.mean(record_['rf_loss'], 2)[0, :], linewidth=2)
plt.semilogy(x_range, np.mean(record_['rf_ridgeless_loss'], 2)[0, :], linewidth=2)
plt.semilogy(x_range, np.mean(record_['RFRed_loss'], 2)[0, :], linewidth=2)
plt.xlabel('Training epochs $T$', fontsize=20)
plt.ylabel('Training Loss', fontsize=20)
plt.tick_params(axis='both', which='major', labelsize=15)
plt.tick_params(axis='both', which='minor', labelsize=15)
plt.title('$\gamma=0.5$')
plt.legend(['Ridge RF', 'Ridgeless RF-SGD', 'RFRed'], fontsize=12)
f.savefig('./results/exp4_{}_loss_under.pdf'.format(dataset), bbox_inches='tight')

f = plt.figure()
plt.plot(x_range, np.mean(record_['rf_error'], 2)[0, :], linewidth=2)
plt.plot(x_range, np.mean(record_['rf_ridgeless_error'], 2)[0, :], linewidth=2)
plt.plot(x_range, np.mean(record_['RFRed_error'], 2)[0, :], linewidth=2)
plt.xlabel('Training epochs $T$', fontsize=20)
plt.ylabel('Test Error', fontsize=20)
plt.tick_params(axis='both', which='major', labelsize=15)
plt.tick_params(axis='both', which='minor', labelsize=15)
plt.title('$\gamma=0.5$')
plt.legend(['Ridge RF', 'Ridgeless RF-SGD', 'RFRed'], fontsize=12)
f.savefig('./results/exp4_{}_error_under.pdf'.format(dataset), bbox_inches='tight')


f = plt.figure()
plt.semilogy(x_range, np.mean(record_['df2_arr'], 2)[0, :], linewidth=2)
plt.semilogy(x_range, np.mean(record_['df2_ridgeless'], 2)[0, :], linewidth=2)
plt.semilogy(x_range, np.mean(record_['df2_RFRed'], 2)[0, :], linewidth=2)
plt.xlabel('Training epochs $T$', fontsize=20)
plt.ylabel('$\widehat{df}_2(\kappa)$', fontsize=20)
plt.tick_params(axis='both', which='major', labelsize=15)
plt.tick_params(axis='both', which='minor', labelsize=15)
plt.title('$\gamma=0.5$')
plt.legend(['Ridge RF', 'Ridgeless RF-SGD', 'RFRed'], fontsize=12)
f.savefig('./results/exp4_{}_df2_under.pdf'.format(dataset), bbox_inches='tight')

f = plt.figure()
plt.semilogy(x_range, np.mean(record_['rf_loss'], 2)[1, :], linewidth=2)
plt.semilogy(x_range, np.mean(record_['rf_ridgeless_loss'], 2)[1, :], linewidth=2)
plt.semilogy(x_range, np.mean(record_['RFRed_loss'], 2)[1, :], linewidth=2)
plt.xlabel('Training epochs $T$', fontsize=20)
plt.ylabel('Training Loss', fontsize=20)
plt.tick_params(axis='both', which='major', labelsize=15)
plt.tick_params(axis='both', which='minor', labelsize=15)
plt.title('$\gamma=2$')
plt.legend(['Ridge RF', 'Ridgeless RF-SGD', 'RFRed'], fontsize=12)
f.savefig('./results/exp4_{}_loss_over.pdf'.format(dataset), bbox_inches='tight')

f = plt.figure()
plt.plot(x_range, np.mean(record_['rf_error'], 2)[1, :], linewidth=2)
plt.plot(x_range, np.mean(record_['rf_ridgeless_error'], 2)[1, :], linewidth=2)
plt.plot(x_range, np.mean(record_['RFRed_error'], 2)[1, :], linewidth=2)
plt.xlabel('Training epochs $T$', fontsize=20)
plt.ylabel('Test Error', fontsize=20)
plt.tick_params(axis='both', which='major', labelsize=15)
plt.tick_params(axis='both', which='minor', labelsize=15)
plt.title('$\gamma=2$')
plt.legend(['Ridge RF', 'Ridgeles RF-SGD', 'RFRed'], fontsize=12)
f.savefig('./results/exp4_{}_error_over.pdf'.format(dataset), bbox_inches='tight')


f = plt.figure()
plt.semilogy(x_range, np.mean(record_['df2_arr'], 2)[0, :], linewidth=2)
plt.semilogy(x_range, np.mean(record_['df2_ridgeless'], 2)[1, :], linewidth=2)
plt.semilogy(x_range, np.mean(record_['df2_RFRed'], 2)[1, :], linewidth=2)
plt.xlabel('Training epochs $T$', fontsize=20)
plt.ylabel('$\widehat{df}_2(\kappa)$', fontsize=20)
plt.tick_params(axis='both', which='major', labelsize=15)
plt.tick_params(axis='both', which='minor', labelsize=15)
plt.title('$\gamma=2$')
plt.legend(['Ridge RF', 'Ridgeless RF-SGD', 'RFRed'], fontsize=12)
f.savefig('./results/exp4_{}_df2_over.pdf'.format(dataset), bbox_inches='tight')
